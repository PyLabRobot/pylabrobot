# %%
# from pylabrobot.resources import (
#     Resource,
#     Carrier, MFXCarrier, PlateCarrier, TipCarrier, TroughCarrier, TubeCarrier,
#     Container, PetriDish, Trough, Tube, Well,
#     Deck, OTDeck, HamiltonDeck, TecanDeck,
#     ItemizedResource, Plate, TipRack, TubeRack,
#     ResourceHolder, PlateHolder,
#     Lid,
#     PlateAdapter,
#     ResourceStack
# )
# # TODO: NestedTipRackStack,
# TODO: Tip,
# TODO: Workcell

# %%
import ast
import os
import re

def find_python_dirs(directory, ignore_list=None):
    """
    Recursively finds all directories containing .py files within a given directory,
    while ignoring specific filenames provided in ignore_list.
    
    :param directory: The root directory to start searching from.
    :param ignore_list: A list of filenames (without .py extension) to ignore.
    :return: A list of directories containing .py files.
    """
    if ignore_list is None:
        ignore_list = set()
    else:
        ignore_list = set(ignore_list)  # Convert to set for faster lookups
    
    python_dirs = set()
    
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".py"):
                if all([
                    file[:-3] not in ignore_list,
                    "test" not in file,
                    "opentrons" not in root
                ]):
                    python_dirs.add(os.path.join(root, file))
    
    return sorted(python_dirs)

def extract_functions_with_imports(file_path, class_list, optional_attr=None):
    """
    Parses a Python file to find functions that return instances of specific classes.
    
    :param file_path: Path to the Python file to analyze.
    :param class_list: List of class names to check against.
    :param optional_attr: List of optional attributes to extract from the docstring.
    :return: Dictionary mapping function names to the class they return, including the 
             directory path, catalog numbers, material, manufacturer, manufacturer_link, 
             notes, and additional optional attributes.
    """
    if optional_attr is None:
        optional_attr = []
    
    with open(file_path, "r", encoding="utf-8") as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imported_classes = set(class_list)  # Use the provided list of classes
    
    function_map = {}
    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            func_data = {
                "resource_type": None,
                "manufacturer": None,
                "brand": None,
                "cat_no": [],
                "manufacturer_link": None,
                "material": None,
                "notes": None,
                "plr_directory": file_path,
            }
            
            # Extract manufacturer from the first subdirectory after "resources"
            path_parts = os.path.normpath(file_path).split(os.path.sep)
            if "resources" in path_parts:
                res_index = path_parts.index("resources")
                if res_index + 1 < len(path_parts):
                    manufacturer = path_parts[res_index + 1]
                    func_data["manufacturer"] = manufacturer.capitalize()
            
            # Check for return statement
            for stmt in node.body:
                if isinstance(stmt, ast.Return) and isinstance(stmt.value, ast.Call):
                    if isinstance(stmt.value.func, ast.Name) and stmt.value.func.id in imported_classes:
                        func_data["resource_type"] = stmt.value.func.id
            
            # Check for catalog numbers, material, manufacturer link, notes, and optional attributes in the docstring
            if node.body and isinstance(node.body[0], ast.Expr) and isinstance(node.body[0].value, ast.Str):
                docstring = node.body[0].value.s
                
                # Extract catalog numbers (handles both "cat. no." and "cat. no.s:")
                cat_match = re.search(r'cat\. no\.?s?:\s*([\w-]+(?:,\s*[\w-]+)*)', docstring, re.IGNORECASE)
                if cat_match:
                    func_data["cat_no"] = [num.strip() for num in cat_match.group(1).split(",")]
                
                # Extract manufacturer_link (ensures only the correct link is captured)
                link_match = re.search(r'manufacturer_link:\s*(https?://\S+)', docstring, re.IGNORECASE)
                if link_match:
                    link_start = link_match.start(1)
                    link_lines = []
                    for line in docstring[link_start:].split("\n"):
                        stripped_line = line.strip()
                        if stripped_line.startswith("-"):
                            break
                        link_lines.append(stripped_line)
                    func_data["manufacturer_link"] = "".join(link_lines)
                
                # Extract notes
                notes_match = re.search(r'notes:\s*(.*)', docstring, re.IGNORECASE)
                if notes_match:
                    func_data["notes"] = notes_match.group(1).strip()
                
                # Extract optional attributes
                for attr in optional_attr:
                    attr_match = re.search(fr'{attr}:\s*(.*)', docstring, re.IGNORECASE)
                    if attr_match:
                        func_data[attr] = attr_match.group(1).strip()
            
            if func_data["resource_type"]:
                function_map[node.name] = func_data
    
    return function_map

# Example usage:
class_list = ["Resource", "Carrier", "MFXCarrier", "PlateCarrier", "TipCarrier", "TroughCarrier", "TubeCarrier",
              "Container", "PetriDish", "Trough", "Tube", "Well", "Deck", "OTDeck", "HamiltonDeck", "TecanDeck",
              "ItemizedResource", "Plate", "TipRack", "TubeRack", "ResourceHolder", "PlateHolder", "Lid", 
              "PlateAdapter", "ResourceStack"]

ignore_list = [
    "__init__"
]

all_py_files_dict = find_python_dirs("pylabrobot/resources/", ignore_list=ignore_list)


plr_rl_summary_dict = {}
for py_file in all_py_files_dict:
    plr_rl_summary_dict.update(
        extract_functions_with_imports(py_file, class_list, optional_attr=["brand", "material", "tc_treated"])
    )

# %%
# %%time

plr_rl_summary_dict = {}
for py_file in all_py_files_dict:
    plr_rl_summary_dict.update(
        extract_functions_with_imports(py_file, class_list, optional_attr=["brand", "material", "Tissue culture treated"])
    )
# Out:
# CPU times: user 95.5 ms, sys: 6.9 ms, total: 102 ms
# Wall time: 309 ms

# %%
import pandas as pd

# %%
df = pd.DataFrame(plr_rl_summary_dict).T
df
# Out:
#                                              resource_type   manufacturer  \
# AGenBio_4_wellplate_Vb                               Plate        Agenbio
# AGenBio_1_troughplate_190000uL_Fl                    Plate        Agenbio
# AGenBio_1_troughplate_100000uL_Fl                    Plate        Agenbio
# Alpaqua_96_magnum_flx                         PlateAdapter        Alpaqua
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb         Plate         Azenta
# ...                                                    ...            ...
# Thermo_TS_96_wellplate_1200ul_Rb                     Plate  Thermo_fisher
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate          Plate  Thermo_fisher
# Thermo_Nunc_96_well_plate_1300uL_Rb                  Plate  Thermo_fisher
# ThermoFisherMatrixTrough8094                        Trough  Thermo_fisher
# VWRReagentReservoirs25mL                            Trough            Vwr
#
#                                                            brand      cat_no  \
# AGenBio_4_wellplate_Vb                                      None          []
# AGenBio_1_troughplate_190000uL_Fl                           None          []
# AGenBio_1_troughplate_100000uL_Fl                           None          []
# Alpaqua_96_magnum_flx                                       None   [A000400]
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb                None  [4ti-0960]
# ...                                                          ...         ...
# Thermo_TS_96_wellplate_1200ul_Rb              Thermo Scientific.    [AB1127]
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate                 None   [4483354]
# Thermo_Nunc_96_well_plate_1300uL_Rb                         None          []
# ThermoFisherMatrixTrough8094                                None          []
# VWRReagentReservoirs25mL                                    None          []
#
#                                              manufacturer_link  \
# AGenBio_4_wellplate_Vb                                    None
# AGenBio_1_troughplate_190000uL_Fl                         None
# AGenBio_1_troughplate_100000uL_Fl                         None
# Alpaqua_96_magnum_flx                                     None
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb              None
# ...                                                        ...
# Thermo_TS_96_wellplate_1200ul_Rb                          None
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate               None
# Thermo_Nunc_96_well_plate_1300uL_Rb                       None
# ThermoFisherMatrixTrough8094                              None
# VWRReagentReservoirs25mL                                  None
#
#                                                                               material  \
# AGenBio_4_wellplate_Vb                                                   Polypropylene
# AGenBio_1_troughplate_190000uL_Fl                                        Polypropylene
# AGenBio_1_troughplate_100000uL_Fl                                        Polypropylene
# Alpaqua_96_magnum_flx                                                             None
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb  Polypropylene wells, polycarbonate frame
# ...                                                                                ...
# Thermo_TS_96_wellplate_1200ul_Rb                 Polypropylene (AB-1068, polystyrene).
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate              Polycarbonate, Polypropylene.
# Thermo_Nunc_96_well_plate_1300uL_Rb                                               None
# ThermoFisherMatrixTrough8094                                                      None
# VWRReagentReservoirs25mL                                                          None
#
#                                              notes  \
# AGenBio_4_wellplate_Vb                        None
# AGenBio_1_troughplate_190000uL_Fl             None
# AGenBio_1_troughplate_100000uL_Fl             None
# Alpaqua_96_magnum_flx                         None
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb  None
# ...                                            ...
# Thermo_TS_96_wellplate_1200ul_Rb              None
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate   None
# Thermo_Nunc_96_well_plate_1300uL_Rb           None
# ThermoFisherMatrixTrough8094                  None
# VWRReagentReservoirs25mL                      None
#
#                                                                                plr_directory  \
# AGenBio_4_wellplate_Vb                                pylabrobot/resources/agenbio/plates.py
# AGenBio_1_troughplate_190000uL_Fl                     pylabrobot/resources/agenbio/plates.py
# AGenBio_1_troughplate_100000uL_Fl                     pylabrobot/resources/agenbio/plates.py
# Alpaqua_96_magnum_flx                         pylabrobot/resources/alpaqua/magnetic_racks.py
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb           pylabrobot/resources/azenta/plates.py
# ...                                                                                      ...
# Thermo_TS_96_wellplate_1200ul_Rb                pylabrobot/resources/thermo_fisher/plates.py
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate     pylabrobot/resources/thermo_fisher/plates.py
# Thermo_Nunc_96_well_plate_1300uL_Rb             pylabrobot/resources/thermo_fisher/plates.py
# ThermoFisherMatrixTrough8094                   pylabrobot/resources/thermo_fisher/troughs.py
# VWRReagentReservoirs25mL                                 pylabrobot/resources/vwr/troughs.py
#
#                                              Tissue culture treated
# AGenBio_4_wellplate_Vb                                          NaN
# AGenBio_1_troughplate_190000uL_Fl                               NaN
# AGenBio_1_troughplate_100000uL_Fl                               NaN
# Alpaqua_96_magnum_flx                                           NaN
# Azenta4titudeFrameStar_96_wellplate_200ul_Vb                    NaN
# ...                                                             ...
# Thermo_TS_96_wellplate_1200ul_Rb                                NaN
# Thermo_AB_96_wellplate_300ul_Vb_EnduraPlate                     NaN
# Thermo_Nunc_96_well_plate_1300uL_Rb                             NaN
# ThermoFisherMatrixTrough8094                                    NaN
# VWRReagentReservoirs25mL                                        NaN
#
# [174 rows x 9 columns]

# %%
df.loc[df.manufacturer == "Corning"]#.manufacturer_link.iloc[0]
# Out:
#                                    resource_type manufacturer   brand  \
# Cor_Axy_24_wellplate_10mL_Vb               Plate      Corning  Axygen
# Cor_Cos_6_wellplate_16800ul_Fb_Lid           Lid      Corning    None
# Cor_Cos_6_wellplate_16800ul_Fb             Plate      Corning  Costar
# Cor_12_wellplate_6900ul_Fb                 Plate      Corning    None
# Cor_24_wellplate_3470ul_Fb                 Plate      Corning    None
# Cor_48_wellplate_1620ul_Fb                 Plate      Corning    None
# Cos_96_wellplate_2mL_Vb                    Plate      Corning    None
# Cor_96_wellplate_360ul_Fb_Lid                Lid      Corning    None
# Cor_96_wellplate_360ul_Fb                  Plate      Corning    None
# Falcon_96_wellplate_Fl                     Plate      Corning    None
# Falcon_96_wellplate_Rb                     Plate      Corning    None
# Falcon_96_wellplate_Fl_Black               Plate      Corning    None
# falcon_tube_50mL                            Tube      Corning    None
# falcon_tube_15mL                            Tube      Corning    None
# Falcon_tube_14mL_Rb                         Tube      Corning    None
#
#                                                             cat_no  \
# Cor_Axy_24_wellplate_10mL_Vb                      [P-DW-10ML-24-C]
# Cor_Cos_6_wellplate_16800ul_Fb_Lid                              []
# Cor_Cos_6_wellplate_16800ul_Fb            [3335, 3506, 3516, 3471]
# Cor_12_wellplate_6900ul_Fb                      [3336, 3512, 3513]
# Cor_24_wellplate_3470ul_Fb          [3337, 3524, 3526, 3527, 3473]
# Cor_48_wellplate_1620ul_Fb                                  [3548]
# Cos_96_wellplate_2mL_Vb                                     [3960]
# Cor_96_wellplate_360ul_Fb_Lid                                   []
# Cor_96_wellplate_360ul_Fb                                       []
# Falcon_96_wellplate_Fl                                    [353072]
# Falcon_96_wellplate_Rb                                    [353077]
# Falcon_96_wellplate_Fl_Black                                    []
# falcon_tube_50mL                                                []
# falcon_tube_15mL                                                []
# Falcon_tube_14mL_Rb                                       [352059]
#
#                                                                     manufacturer_link  \
# Cor_Axy_24_wellplate_10mL_Vb        https://ecatalog.corning.com/life-sciences/b2b...
# Cor_Cos_6_wellplate_16800ul_Fb_Lid                                               None
# Cor_Cos_6_wellplate_16800ul_Fb      https://ecatalog.corning.com/life-sciences/b2b...
# Cor_12_wellplate_6900ul_Fb                                                       None
# Cor_24_wellplate_3470ul_Fb                                                       None
# Cor_48_wellplate_1620ul_Fb                                                       None
# Cos_96_wellplate_2mL_Vb                                                          None
# Cor_96_wellplate_360ul_Fb_Lid                                                    None
# Cor_96_wellplate_360ul_Fb                                                        None
# Falcon_96_wellplate_Fl                                                           None
# Falcon_96_wellplate_Rb                                                           None
# Falcon_96_wellplate_Fl_Black                                                     None
# falcon_tube_50mL                                                                 None
# falcon_tube_15mL                                                                 None
# Falcon_tube_14mL_Rb                                                              None
#
#                                          material notes  \
# Cor_Axy_24_wellplate_10mL_Vb        Polypropylene  None
# Cor_Cos_6_wellplate_16800ul_Fb_Lid           None  None
# Cor_Cos_6_wellplate_16800ul_Fb      Polypropylene  None
# Cor_12_wellplate_6900ul_Fb                   None  None
# Cor_24_wellplate_3470ul_Fb                   None  None
# Cor_48_wellplate_1620ul_Fb                   None  None
# Cos_96_wellplate_2mL_Vb             Polypropylene  None
# Cor_96_wellplate_360ul_Fb_Lid                None  None
# Cor_96_wellplate_360ul_Fb                    None  None
# Falcon_96_wellplate_Fl                Polystyrene  None
# Falcon_96_wellplate_Rb                Polystyrene  None
# Falcon_96_wellplate_Fl_Black                 None  None
# falcon_tube_50mL                             None  None
# falcon_tube_15mL                             None  None
# Falcon_tube_14mL_Rb                 polypropylene  None
#
#                                                                     plr_directory  \
# Cor_Axy_24_wellplate_10mL_Vb        pylabrobot/resources/corning/axygen/plates.py
# Cor_Cos_6_wellplate_16800ul_Fb_Lid  pylabrobot/resources/corning/costar/plates.py
# Cor_Cos_6_wellplate_16800ul_Fb      pylabrobot/resources/corning/costar/plates.py
# Cor_12_wellplate_6900ul_Fb          pylabrobot/resources/corning/costar/plates.py
# Cor_24_wellplate_3470ul_Fb          pylabrobot/resources/corning/costar/plates.py
# Cor_48_wellplate_1620ul_Fb          pylabrobot/resources/corning/costar/plates.py
# Cos_96_wellplate_2mL_Vb             pylabrobot/resources/corning/costar/plates.py
# Cor_96_wellplate_360ul_Fb_Lid       pylabrobot/resources/corning/costar/plates.py
# Cor_96_wellplate_360ul_Fb           pylabrobot/resources/corning/costar/plates.py
# Falcon_96_wellplate_Fl              pylabrobot/resources/corning/falcon/plates.py
# Falcon_96_wellplate_Rb              pylabrobot/resources/corning/falcon/plates.py
# Falcon_96_wellplate_Fl_Black        pylabrobot/resources/corning/falcon/plates.py
# falcon_tube_50mL                     pylabrobot/resources/corning/falcon/tubes.py
# falcon_tube_15mL                     pylabrobot/resources/corning/falcon/tubes.py
# Falcon_tube_14mL_Rb                  pylabrobot/resources/corning/falcon/tubes.py
#
#                                    Tissue culture treated
# Cor_Axy_24_wellplate_10mL_Vb                          NaN
# Cor_Cos_6_wellplate_16800ul_Fb_Lid                    NaN
# Cor_Cos_6_wellplate_16800ul_Fb                        NaN
# Cor_12_wellplate_6900ul_Fb                            NaN
# Cor_24_wellplate_3470ul_Fb                            NaN
# Cor_48_wellplate_1620ul_Fb                            NaN
# Cos_96_wellplate_2mL_Vb                               NaN
# Cor_96_wellplate_360ul_Fb_Lid                         NaN
# Cor_96_wellplate_360ul_Fb                             NaN
# Falcon_96_wellplate_Fl                                NaN
# Falcon_96_wellplate_Rb                                Yes
# Falcon_96_wellplate_Fl_Black                          NaN
# falcon_tube_50mL                                      NaN
# falcon_tube_15mL                                      NaN
# Falcon_tube_14mL_Rb                                   NaN

# %%
{'AGenBio_4_wellplate_Vb': {'resource_type': 'Plate',
  'plr_directory': 'pylabrobot/resources/agenbio',
  'cat_num': None,
  'material': 'Polypropylene',
  'manufacturer': 'Agenbio',
  'manufacturer_link': None,
  'notes': {"tc_treated": True}}},
}
# Out:
#   Cell In[6], line 8
#     }
#     ^
# SyntaxError: unmatched '}'

# %%
plr_rl_summary_dict
