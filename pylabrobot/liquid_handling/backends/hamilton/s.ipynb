# %%
from pylabrobot.liquid_handling.backends.hamilton.STAR_backend import parse_star_fw_string

# %%
resp = "C0ZBid0215er00/00vl0009bb/09Barcode01"
er_index = resp.find("er")
resp.find("vl", er_index + 7), resp.find("bb/", er_index + 7)
# Out:
# (17, 23)

# %%
len("09Barcode01")
# Out:
# 11

# %%
"".find()
# Out:
# <function str.find>
