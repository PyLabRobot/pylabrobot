# %% [markdown]
# # Peeling
#
# {class}`~pylabrobot.capabilities.peeling.peeling.Peeler` controls automated de-seal (peel) cycles for removing plate seals.
#
# ## Walkthrough

# %%
from pylabrobot.capabilities.peeling import Peeler
from pylabrobot.capabilities.peeling.chatterbox import PeelerChatterboxBackend

peeler = Peeler(backend=PeelerChatterboxBackend())
await peeler._on_setup()

# %%
await peeler.peel()

# %% [markdown]
# ## Supported hardware
#
# ```{supported-devices} peeling
# ```
#
# ## API reference
#
# See {class}`~pylabrobot.capabilities.peeling.peeling.Peeler` and {class}`~pylabrobot.capabilities.peeling.peeling.PeelerBackend`.
